# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.colors as mcolors
import seaborn as sns
# %matplotlib inline
import gensim
from gensim.corpora import Dictionary
from gensim.models import LdaModel
from gensim.models.tfidfmodel import TfidfModel
from gensim.matutils import corpus2dense, corpus2csc
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA, SparsePCA
from sklearn.cluster import KMeans, MiniBatchKMeans
from sklearn.metrics import silhouette_score, silhouette_samples
from sklearn.decomposition import SparsePCA, TruncatedSVD
from scipy.sparse import csc_matrix
from sklearn.manifold import TSNE
from bokeh.plotting import figure, output_file, show
from bokeh.models import Label, ColumnDataSource
from bokeh.io import output_notebook
from bokeh.palettes import all_palettes
output_notebook()

sns.set_style('whitegrid')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
def load_dictionary(path='dataframes/dictionary.gensim'):
    return Dictionary.load(path)

# %%
def load_corpus(path='dataframes/corpus.pkl'):
    with open(path, 'rb') as file:
        corpus = pickle.load(file)
    return corpus

# %%
dictionary = load_dictionary('dataframes/dictionary.gensim')
corpus = load_corpus('dataframes/corpus.pkl')

# %%
num_docs = dictionary.num_docs
num_terms = len(dictionary.keys())

print('Number of unique tokens: {}'.format(num_terms))
print('Number of documents: {}'.format(num_docs))
# Out:
# Number of unique tokens: 7037
# Number of documents: 3889

# %%
# Transform BOW model into TF-IDF
tfidf = TfidfModel(corpus)
corpus_tfidf = tfidf[corpus]

# %%
# Transform corpus into dense/sparse matrix
use_tfidf = False

if(use_tfidf):
    corpus_dense = corpus2dense(corpus_tfidf, num_terms, num_docs)    
    corpus_sparse = corpus2csc(corpus_tfidf)                          
else:
    corpus_dense = corpus2dense(corpus, num_terms, num_docs)
    corpus_sparse = corpus2csc(corpus)
    
    
print(corpus_dense.T.shape)
print(corpus_sparse.T.shape)
# Out:
# (3889, 7037)
# (3889, 7037)

# %% [markdown]
# # Scaling TF-IDF features

# %%
mms = MinMaxScaler()
scaled_data = mms.fit_transform(corpus_sparse.T.toarray())
scaled_data.shape
# Out:
# (3889, 7037)

# %% [markdown]
# # Clustering using Kmeans

# %%
kmeans = KMeans(n_clusters=29)
labels = kmeans.fit_predict(scaled_data)
centroids = kmeans.cluster_centers_

# %% [markdown]
# # Find optimal number of clusters (elbow method)

# %%
start = 2
limit = 41
step = 1

sse = []
for i in range(start, limit, step):
    inertia = MiniBatchKMeans(n_clusters=i, random_state=33).fit(scaled_data).inertia_
    sse.append(inertia)
    print('Fit {} clusters - SSE: {}'.format(i, inertia))
# Out:
# Fit 2 clusters - SSE: 40901.866795347356
# Fit 3 clusters - SSE: 40897.206991053274
# Fit 4 clusters - SSE: 39327.558350268926
# Fit 5 clusters - SSE: 40881.98033538551
# Fit 6 clusters - SSE: 40882.024133045765
# Fit 7 clusters - SSE: 40818.26803013682
# Fit 8 clusters - SSE: 39466.98923367421
# Fit 9 clusters - SSE: 40714.3270289259
# Fit 10 clusters - SSE: 38413.88962329098
# Fit 11 clusters - SSE: 39450.9199603357
# Fit 12 clusters - SSE: 40711.20414213037
# Fit 13 clusters - SSE: 39400.225923308055
# Fit 14 clusters - SSE: 39491.99578258696
# Fit 15 clusters - SSE: 39139.53693328102
# Fit 16 clusters - SSE: 39465.7420526496
# Fit 17 clusters - SSE: 39429.09884160891
# Fit 18 clusters - SSE: 39240.60364579542
# Fit 19 clusters - SSE: 39292.8962327942
# Fit 20 clusters - SSE: 39205.94012534321
# Fit 21 clusters - SSE: 38884.34771243561
# Fit 22 clusters - SSE: 40696.057043776986
# Fit 23 clusters - SSE: 39053.10826448946
# Fit 24 clusters - SSE: 39349.836457269754
# Fit 25 clusters - SSE: 39283.51167439104
# Fit 26 clusters - SSE: 39329.37729642613
# Fit 27 clusters - SSE: 38196.038276591265
# Fit 28 clusters - SSE: 39072.92987601981
# Fit 29 clusters - SSE: 39669.612115348085
# Fit 30 clusters - SSE: 38028.34203376353
# Fit 31 clusters - SSE: 39059.78676387281
# Fit 32 clusters - SSE: 40583.45437789348
# Fit 33 clusters - SSE: 39180.87977648169
# Fit 34 clusters - SSE: 39284.11017191065
# Fit 35 clusters - SSE: 39018.059918052226
# Fit 36 clusters - SSE: 40522.860476675814
# Fit 37 clusters - SSE: 39326.320125198996
# Fit 38 clusters - SSE: 39260.47651442472
# Fit 39 clusters - SSE: 39102.982385495496
# Fit 40 clusters - SSE: 40494.630211241194

# %%
def plot_clustering_sse(sse, limit, start, step):
    x = range(start, limit, step)
    plt.figure(figsize=(10, 8))
    plt.plot(x, sse)
    plt.xlabel("Num Clusters")
    plt.ylabel("SSE")
    #plt.legend(("sse"), loc='best')
    
plot_clustering_sse(sse=sse, limit=limit, start=start, step=step)

# %%
# best kmeans model is with 30 clusters, similar to best LDA model with 29 topics!
optimal_model = MiniBatchKMeans(n_clusters=30, random_state=33)
labels = optimal_model.fit_predict(scaled_data)
centroids = optimal_model.cluster_centers_

# %%
print('Dimensions of clustering data: {}'.format(scaled_data.shape))
print('Dimensions of cluster centroids: {}'.format(centroids.shape))
#for word in dictionary.values():
#    print(word)
# Out:
# Dimensions of clustering data: (3889, 7037)
# Dimensions of cluster centroids: (30, 7037)

# %% [markdown]
# ## Append centroids to scaled data, because of t-SNE

# %%
all_data = np.concatenate((scaled_data, centroids), axis=0)
print('Dimensions of clustering data and centroids: {}'.format(all_data.shape))
# Out:
# Dimensions of clustering data and centroids: (3919, 7037)

# %% [markdown]
# # Top terms for each cluster

# %%
print("Top terms per cluster:\n")

order_centroids = centroids.argsort()[:, ::-1]

if(use_tfidf):
    terms = list({dictionary.get(id): value for doc in corpus_tfidf for id, value in doc}.keys())
else:
    terms = list(dictionary.values())

cluster_top_words = []

for i in range(30):
    print('Cluster {}'.format(i))
    words = []
    for ind in order_centroids[i, :10]:
        print(terms[ind])
        words.append(terms[ind])
    cluster_top_words.append(words)
    print()
# Out:
# Top terms per cluster:
#
# Cluster 0
# difficulty
# latter
# correct
# ensure
# lead
# simply
# assume
# fully
# responsibility
# doubt
#
# Cluster 1
# issuer
# card
# certify_preceding
# oxford_english
# interchange
# narrower
# highest
# incidence
# recorded
# functionality
#
# Cluster 2
# uncritically
# immigration_multicultural
# imprison
# following
# indonesian
# plot
# appellant
# unable
# persecute
# genuineness
#
# Cluster 3
# economical
# promptly
# allsop
# inadequacy
# bill
# contaminate
# really
# naturally
# moment
# reliance_placed
#
# Cluster 4
# constitute
# mere
# contrary
# simply
# meaning
# consequence
# enable
# apparent
# none
# relief
#
# Cluster 5
# island
# willingness
# furniture
# unit
# branson
# interpolate
# establishe
# changed
# strenuously
# commenced
#
# Cluster 6
# wrongdoer
# returnable
# transpire
# misapply
# conveniently
# prayer
# falsely
# bench
# prevail
# collectively
#
# Cluster 7
# flick_associate
# unrepresente
# forth
# certify_preceding
# refused_supposing
# refused
# unsupported
# seeking
# merit
# tribunal
#
# Cluster 8
# troubled
# concluding
# divest
# judge
# intolerable
# removed
# bias
# fortunately
# probability
# inclination
#
# Cluster 9
# enlarge
# ignorance
# probation
# dictate
# inappropriately
# accede
# urgently
# misapply
# administrative_decision
# frankly
#
# Cluster 10
# associate_dated
# tribunal
# insuperable
# worthless
# curiously
# relief
# appellant
# constitute
# invite
# nine_numbered
#
# Cluster 11
# conformably
# soft
# reliant
# customarily
# insuperable
# worry
# manufacturing
# tablet
# sudden
# gist
#
# Cluster 12
# underline
# recognisable
# officially
# grave
# opponent
# impression
# confused
# retained
# preparedness
# hair
#
# Cluster 13
# contradiction
# adjournment
# flee
# wife
# notable
# discrepancy
# appellant
# refuse_grant
# minded
# asylum
#
# Cluster 14
# nine_numbered
# eleven_numbered
# kenny_associate
# associate_date
# tribunal
# certify_preceding
# helmore
# merit
# file_serve
# fourteen_numbered
#
# Cluster 15
# unconnecte
# facet
# unconnected
# conciliation_arbitration
# crystallise
# unrelated
# payee
# superficial
# properly_characterised
# giving_rise
#
# Cluster 16
# touchstone
# flick_associate
# slip
# disappoint
# disturb
# inadequacy
# allowed
# justifiably
# excessively
# anywhere
#
# Cluster 17
# tribunal
# certify_preceding
# appellant
# merit
# relief
# constitute
# error
# finding
# thirty_numbered
# failure
#
# Cluster 18
# warrant_reconsideration
# inevitably
# opined
# occupied
# ostensibly
# abandonment
# prolong
# recognising
# joined
# unnecessarily
#
# Cluster 19
# soon_practicable
# unsuccessfully
# creditor_petition
# found
# petition
# bankruptcy
# entertain
# paraphrase
# avenue
# finality
#
# Cluster 20
# certify_preceding
# trivial
# suggestive
# character
# informative
# dismissed
# demonstrated
# recent
# insufficient
# conceal
#
# Cluster 21
# associate_dated
# organise
# respondents
# apprise
# vigorous
# organising
# truncate
# airc
# injunction
# workplace_relation
#
# Cluster 22
# complicated
# flick_associate
# federal_magistrate
# entrust
# expeditiously
# powers_conferred
# unconfined
# myriad
# canvass
# inferior
#
# Cluster 23
# reluctance
# self_represente
# self_represented
# unreasonably
# litigant
# merit
# public_prosecution
# overcome
# indemnity
# deprive
#
# Cluster 24
# wound_insolvency
# appointment_receiver
# carey
# specialty
# secured
# guarantor
# treated
# procedural
# mortgagee
# receivers_manager
#
# Cluster 25
# subparagraph
# millions_dollar
# exception
# seventh
# reading_speech
# eighth
# episode
# woman
# viewer
# prescribe
#
# Cluster 26
# drawn_attention
# directions_hearing
# obliged
# engaged
# afford
# underlying
# regularise
# infrequently
# contended
# criminality
#
# Cluster 27
# nationally
# sought
# exhaustive_list
# entry
# contextual
# official
# imposing_pecuniary
# dislocation
# subsume
# treated
#
# Cluster 28
# kenny_associate
# appreciated
# faithfully
# initio
# aside
# borne_mind
# conceal
# felt
# improperly
# explanation_delay
#
# Cluster 29
# self_represented
# ameliorate
# alleviate
# comfortably
# obtained
# behavioural
# forensic
# expression
# series
# diagnostic

# %% [markdown]
# # t-SNE dimensionality reduction

# %%
# first reduce dimensionality using PCA, and then pass it to t-SNE
pca = PCA(n_components=1000)       # probati eventualno i SparsePCA
pca_data = pca.fit_transform(all_data)
print('Explained variation: {}'.format(np.sum(pca.explained_variance_ratio_)))
# Out:
# Explained variation: 0.8455155651461557

# %%
tsne_model = TSNE(n_components=2, verbose=1, random_state=33)

# %%
tsne_res = tsne_model.fit_transform(pca_data)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 3919 samples in 0.377s...
# [t-SNE] Computed neighbors for 3919 samples in 67.908s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3919
# [t-SNE] Computed conditional probabilities for sample 2000 / 3919
# [t-SNE] Computed conditional probabilities for sample 3000 / 3919
# [t-SNE] Computed conditional probabilities for sample 3919 / 3919
# [t-SNE] Mean sigma: 0.233507
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 107.147476
# [t-SNE] KL divergence after 1000 iterations: 2.528986

# %%
tsne_df = pd.DataFrame(tsne_res[:scaled_data.shape[0], :], columns=['x1', 'x2'])
tsne_df['cluster'] = labels
tsne_df.head()
# Out:
#           x1         x2  cluster
# 0 -10.235938  15.635242        4
# 1 -26.077745  27.460308       14
# 2  -7.040305   4.432654       17
# 3  18.312267  20.706522        0
# 4  15.028029  14.916729        4

# %%
# get transformed points for all centroids
tsne_centroids = tsne_res[scaled_data.shape[0]:, :]

# %%
plt.figure(figsize=(15, 15))

sns.scatterplot(x=tsne_df['x1'], y=tsne_df['x2'], hue=tsne_df['cluster'], legend='full', palette=sns.color_palette("hls", 30))
sns.scatterplot(x=tsne_centroids[:, 0], y=tsne_centroids[:, 1], marker='X', s=100, color='darkred')

# %%
#colors = np.array([color for name, color in mcolors.XKCD_COLORS.items()])

#plot = figure(title="t-SNE for {} clusters".format(29), 
              #plot_width=900, plot_height=900)

#plot.scatter(x=tsne_df['x1'], y=tsne_df['x2'], color=tsne_df['cluster'].apply(lambda x: colors[x]))

#show(plot)

# %% [markdown]
# # Loading LDA topic model and visualization of topics using t-SNE

# %%
def load_model(path='LDA model/lda.model'):
    return LdaModel.load(path)

# %%
lda_model = load_model('LDA model/lda.model')
num_topics = lda_model.num_topics
print('Number of topics: {}'.format(num_topics))
# Out:
# Number of topics: 29

# %%
# Topic weights
topic_weights = []
for i, row_list in enumerate(lda_model[corpus]):
    topic_weights.append([w for j, w in row_list[0]])

# %%
topic_weights_arr = pd.DataFrame(topic_weights).fillna(0).values

# %%
# threshold for better separation
filter_weights = False

if(filter_weights):
    topic_weights_arr = topic_weights_arr[np.amax(topic_weights_arr, axis=1) > 0.35]

# %%
dominant_topic = np.argmax(topic_weights_arr, axis=1)

# %%
tsne_model = TSNE(n_components=2, verbose=1, random_state=33)

# %%
# fit t-SNE model on LDA topics
tsne_lda = tsne_model.fit_transform(topic_weights_arr)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 3889 samples in 0.006s...
# [t-SNE] Computed neighbors for 3889 samples in 1.474s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3889
# [t-SNE] Computed conditional probabilities for sample 2000 / 3889
# [t-SNE] Computed conditional probabilities for sample 3000 / 3889
# [t-SNE] Computed conditional probabilities for sample 3889 / 3889
# [t-SNE] Mean sigma: 0.093625
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 83.117378
# [t-SNE] KL divergence after 1000 iterations: 1.623225

# %%
plt.figure(figsize=(15, 15))

sns.scatterplot(x=tsne_lda[:, 0], y=tsne_lda[:, 1])

# %% [markdown]
# # Plot topics

# %%
# num_words = all words in dictionary!
topics = lda_model.show_topics(num_topics=num_topics, num_words=scaled_data.shape[1], formatted=False)
len(topics[0][1])
# Out:
# 1000

# %%
scaled_data.shape[1]
# Out:
# 7037
