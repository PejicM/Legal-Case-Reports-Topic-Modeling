# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.colors as mcolors
import seaborn as sns
# %matplotlib inline
import gensim
from gensim.corpora import Dictionary
from gensim.models import LdaModel
from gensim.models.tfidfmodel import TfidfModel
from gensim.matutils import corpus2dense, corpus2csc
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA, SparsePCA
from sklearn.cluster import KMeans, MiniBatchKMeans
from sklearn.metrics import silhouette_score, silhouette_samples
from sklearn.decomposition import SparsePCA, TruncatedSVD
from scipy.sparse import csc_matrix
from sklearn.manifold import TSNE

sns.set_style('whitegrid')

# %%
def load_dictionary(path='dataframes/dictionary.gensim'):
    return Dictionary.load(path)

# %%
def load_corpus(path='dataframes/corpus.pkl'):
    with open(path, 'rb') as file:
        corpus = pickle.load(file)
    return corpus

# %%
dictionary = load_dictionary('dataframes/dictionary.gensim')
corpus = load_corpus('dataframes/corpus.pkl')

# %%
num_docs = dictionary.num_docs
num_terms = len(dictionary.keys())

print('Number of unique tokens: {}'.format(num_terms))
print('Number of documents: {}'.format(num_docs))
# Out:
# Number of unique tokens: 7037
# Number of documents: 3889

# %%
# Transform BOW model into TF-IDF
tfidf = TfidfModel(corpus)
corpus_tfidf = tfidf[corpus]

# %%
# Transform corpus into dense/sparse matrix
use_tfidf = False

if(use_tfidf):
    corpus_dense = corpus2dense(corpus_tfidf, num_terms, num_docs)    
    corpus_sparse = corpus2csc(corpus_tfidf)                          
else:
    corpus_dense = corpus2dense(corpus, num_terms, num_docs)
    corpus_sparse = corpus2csc(corpus)
    
    
print(corpus_dense.T.shape)
print(corpus_sparse.T.shape)
# Out:
# (3889, 7037)
# (3889, 7037)

# %% [markdown]
# # Feature scaling

# %%
mms = MinMaxScaler()
scaled_data = mms.fit_transform(corpus_sparse.T.toarray())
scaled_data.shape
# Out:
# (3889, 7037)

# %% [markdown]
# # Clustering using Kmeans

# %%
kmeans = KMeans(n_clusters=29)
labels = kmeans.fit_predict(scaled_data)
centroids = kmeans.cluster_centers_

# %% [markdown]
# # Find optimal number of clusters

# %%
start = 2
limit = 41
step = 1

sse = []
for i in range(start, limit, step):
    inertia = MiniBatchKMeans(n_clusters=i, random_state=33).fit(scaled_data).inertia_
    sse.append(inertia)
    print('Fit {} clusters - SSE: {}'.format(i, inertia))
# Out:
# Fit 2 clusters - SSE: 40901.866795347356
# Fit 3 clusters - SSE: 40897.206991053274
# Fit 4 clusters - SSE: 39327.558350268926
# Fit 5 clusters - SSE: 40881.98033538551
# Fit 6 clusters - SSE: 40882.024133045765
# Fit 7 clusters - SSE: 40818.26803013682
# Fit 8 clusters - SSE: 39466.98923367421
# Fit 9 clusters - SSE: 40714.3270289259
# Fit 10 clusters - SSE: 38413.88962329098
# Fit 11 clusters - SSE: 39450.9199603357
# Fit 12 clusters - SSE: 40711.20414213037
# Fit 13 clusters - SSE: 39400.225923308055
# Fit 14 clusters - SSE: 39491.99578258696
# Fit 15 clusters - SSE: 39139.53693328102
# Fit 16 clusters - SSE: 39465.7420526496
# Fit 17 clusters - SSE: 39429.09884160891
# Fit 18 clusters - SSE: 39240.60364579542
# Fit 19 clusters - SSE: 39292.8962327942
# Fit 20 clusters - SSE: 39205.94012534321
# Fit 21 clusters - SSE: 38884.34771243561
# Fit 22 clusters - SSE: 40696.057043776986
# Fit 23 clusters - SSE: 39053.10826448946
# Fit 24 clusters - SSE: 39349.836457269754
# Fit 25 clusters - SSE: 39283.51167439104
# Fit 26 clusters - SSE: 39329.37729642613
# Fit 27 clusters - SSE: 38196.038276591265
# Fit 28 clusters - SSE: 39072.92987601981
# Fit 29 clusters - SSE: 39669.612115348085
# Fit 30 clusters - SSE: 38028.34203376353
# Fit 31 clusters - SSE: 39059.78676387281
# Fit 32 clusters - SSE: 40583.45437789348
# Fit 33 clusters - SSE: 39180.87977648169
# Fit 34 clusters - SSE: 39284.11017191065
# Fit 35 clusters - SSE: 39018.059918052226
# Fit 36 clusters - SSE: 40522.860476675814
# Fit 37 clusters - SSE: 39326.320125198996
# Fit 38 clusters - SSE: 39260.47651442472
# Fit 39 clusters - SSE: 39102.982385495496
# Fit 40 clusters - SSE: 40494.630211241194

# %%
def plot_clustering_sse(sse, limit, start, step):
    x = range(start, limit, step)
    plt.figure(figsize=(10, 8))
    plt.plot(x, sse)
    plt.xlabel("Num Clusters")
    plt.ylabel("SSE")
    #plt.legend(("sse"), loc='best')
    
plot_clustering_sse(sse=sse, limit=limit, start=start, step=step)

# %%
# best kmeans model is with 30 clusters, similar to best LDA model with 29 topics!
optimal_model = MiniBatchKMeans(n_clusters=30, random_state=33)
labels = optimal_model.fit_predict(scaled_data)
centroids = optimal_model.cluster_centers_

# %%
print('Dimensions of clustering data: {}'.format(scaled_data.shape))
print('Dimensions of cluster centroids: {}'.format(centroids.shape))
#for word in dictionary.values():
#    print(word)
# Out:
# Dimensions of clustering data: (3889, 7037)
# Dimensions of cluster centroids: (30, 7037)

# %% [markdown]
# ## Append centroids to scaled data, because of t-SNE

# %%
all_data = np.concatenate((scaled_data, centroids), axis=0)
print('Dimensions of clustering data and centroids: {}'.format(all_data.shape))
# Out:
# Dimensions of clustering data and centroids: (3919, 7037)

# %% [markdown]
# # Top terms for each cluster

# %%
print("Top terms per cluster:\n")

order_centroids = centroids.argsort()[:, ::-1]

if(use_tfidf):
    terms = list({dictionary.get(id): value for doc in corpus_tfidf for id, value in doc}.keys())
else:
    terms = list(dictionary.values())

cluster_top_words = []

for i in range(30):
    print('Cluster {}'.format(i))
    words = []
    for ind in order_centroids[i, :10]:
        print(terms[ind])
        words.append(terms[ind])
    cluster_top_words.append(words)
    print()
# Out:
# Top terms per cluster:
#
# Cluster 0
# difficulty
# latter
# correct
# ensure
# lead
# simply
# assume
# fully
# responsibility
# doubt
#
# Cluster 1
# issuer
# card
# certify_preceding
# oxford_english
# interchange
# narrower
# highest
# incidence
# recorded
# functionality
#
# Cluster 2
# uncritically
# immigration_multicultural
# imprison
# following
# indonesian
# plot
# appellant
# unable
# persecute
# genuineness
#
# Cluster 3
# economical
# promptly
# allsop
# inadequacy
# bill
# contaminate
# really
# naturally
# moment
# reliance_placed
#
# Cluster 4
# constitute
# mere
# contrary
# simply
# meaning
# consequence
# enable
# apparent
# none
# relief
#
# Cluster 5
# island
# willingness
# furniture
# unit
# branson
# interpolate
# establishe
# changed
# strenuously
# commenced
#
# Cluster 6
# wrongdoer
# returnable
# transpire
# misapply
# conveniently
# prayer
# falsely
# bench
# prevail
# collectively
#
# Cluster 7
# flick_associate
# unrepresente
# forth
# certify_preceding
# refused_supposing
# refused
# unsupported
# seeking
# merit
# tribunal
#
# Cluster 8
# troubled
# concluding
# divest
# judge
# intolerable
# removed
# bias
# fortunately
# probability
# inclination
#
# Cluster 9
# enlarge
# ignorance
# probation
# dictate
# inappropriately
# accede
# urgently
# misapply
# administrative_decision
# frankly
#
# Cluster 10
# associate_dated
# tribunal
# insuperable
# worthless
# curiously
# relief
# appellant
# constitute
# invite
# nine_numbered
#
# Cluster 11
# conformably
# soft
# reliant
# customarily
# insuperable
# worry
# manufacturing
# tablet
# sudden
# gist
#
# Cluster 12
# underline
# recognisable
# officially
# grave
# opponent
# impression
# confused
# retained
# preparedness
# hair
#
# Cluster 13
# contradiction
# adjournment
# flee
# wife
# notable
# discrepancy
# appellant
# refuse_grant
# minded
# asylum
#
# Cluster 14
# nine_numbered
# eleven_numbered
# kenny_associate
# associate_date
# tribunal
# certify_preceding
# helmore
# merit
# file_serve
# fourteen_numbered
#
# Cluster 15
# unconnecte
# facet
# unconnected
# conciliation_arbitration
# crystallise
# unrelated
# payee
# superficial
# properly_characterised
# giving_rise
#
# Cluster 16
# touchstone
# flick_associate
# slip
# disappoint
# disturb
# inadequacy
# allowed
# justifiably
# excessively
# anywhere
#
# Cluster 17
# tribunal
# certify_preceding
# appellant
# merit
# relief
# constitute
# error
# finding
# thirty_numbered
# failure
#
# Cluster 18
# warrant_reconsideration
# inevitably
# opined
# occupied
# ostensibly
# abandonment
# prolong
# recognising
# joined
# unnecessarily
#
# Cluster 19
# soon_practicable
# unsuccessfully
# creditor_petition
# found
# petition
# bankruptcy
# entertain
# paraphrase
# avenue
# finality
#
# Cluster 20
# certify_preceding
# trivial
# suggestive
# character
# informative
# dismissed
# demonstrated
# recent
# insufficient
# conceal
#
# Cluster 21
# associate_dated
# organise
# respondents
# apprise
# vigorous
# organising
# truncate
# airc
# injunction
# workplace_relation
#
# Cluster 22
# complicated
# flick_associate
# federal_magistrate
# entrust
# expeditiously
# powers_conferred
# unconfined
# myriad
# canvass
# inferior
#
# Cluster 23
# reluctance
# self_represente
# self_represented
# unreasonably
# litigant
# merit
# public_prosecution
# overcome
# indemnity
# deprive
#
# Cluster 24
# wound_insolvency
# appointment_receiver
# carey
# specialty
# secured
# guarantor
# treated
# procedural
# mortgagee
# receivers_manager
#
# Cluster 25
# subparagraph
# millions_dollar
# exception
# seventh
# reading_speech
# eighth
# episode
# woman
# viewer
# prescribe
#
# Cluster 26
# drawn_attention
# directions_hearing
# obliged
# engaged
# afford
# underlying
# regularise
# infrequently
# contended
# criminality
#
# Cluster 27
# nationally
# sought
# exhaustive_list
# entry
# contextual
# official
# imposing_pecuniary
# dislocation
# subsume
# treated
#
# Cluster 28
# kenny_associate
# appreciated
# faithfully
# initio
# aside
# borne_mind
# conceal
# felt
# improperly
# explanation_delay
#
# Cluster 29
# self_represented
# ameliorate
# alleviate
# comfortably
# obtained
# behavioural
# forensic
# expression
# series
# diagnostic

# %% [markdown]
# # t-SNE dimensionality reduction

# %%
# first reduce dimensionality using PCA, and then pass it to t-SNE
# mala usteda vremena, t-SNE je dosta spor u ovoj situaciji
pca = PCA(n_components=1000)       # probati eventualno i SparsePCA
pca_data = pca.fit_transform(all_data)
print('Explained variation: {}'.format(np.sum(pca.explained_variance_ratio_)))
# Out:
# Explained variation: 0.8455498695666961

# %%
tsne_model = TSNE(n_components=2, verbose=1, random_state=33)

# %%
tsne_res = tsne_model.fit_transform(pca_data)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 3919 samples in 0.232s...
# [t-SNE] Computed neighbors for 3919 samples in 28.423s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3919
# [t-SNE] Computed conditional probabilities for sample 2000 / 3919
# [t-SNE] Computed conditional probabilities for sample 3000 / 3919
# [t-SNE] Computed conditional probabilities for sample 3919 / 3919
# [t-SNE] Mean sigma: 0.233427
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 104.066170
# [t-SNE] KL divergence after 1000 iterations: 2.535322

# %%
tsne_df = pd.DataFrame(tsne_res[:scaled_data.shape[0], :], columns=['x1', 'x2'])
tsne_df['cluster'] = labels
tsne_df.head()
# Out:
#           x1         x2  cluster
# 0   3.513393  14.625737        4
# 1 -30.131029  23.712526       14
# 2  18.660135  -2.326115       17
# 3  -3.029949 -30.468782        0
# 4  -3.786259 -20.382168        4

# %%
# get transformed points for all centroids
tsne_centroids = tsne_res[scaled_data.shape[0]:, :]

# %%
plt.figure(figsize=(15, 15))

sns.scatterplot(x=tsne_df['x1'], y=tsne_df['x2'], hue=tsne_df['cluster'], legend='full', palette=sns.color_palette("hls", 30))
sns.scatterplot(x=tsne_centroids[:, 0], y=tsne_centroids[:, 1], marker='X', s=100, color='darkred')

# %% [markdown]
# # Loading LDA topic model and visualization of topics using t-SNE

# %% [markdown]
# ## Ovde je radjeno sa raspodelom tema za svaki dokument

# %%
def load_model(path='LDA model/lda.model'):
    return LdaModel.load(path)

# %%
lda_model = load_model('LDA model/lda.model')
num_topics = lda_model.num_topics
print('Number of topics: {}'.format(num_topics))
# Out:
# Number of topics: 29

# %%
topics_distribution = []

for doc in corpus:
    topics = [] 
    topic_pairs = lda_model.get_document_topics(doc, minimum_probability=0.0)
    
    for pair in topic_pairs:
        topics.append(pair[1])
        
    topics_distribution.append(topics)
    
print(len(topics_distribution))
# Out:
# 3889

# %%
dominant_topic = np.argmax(topics_distribution, axis=1)
dominant_topic
# Out:
# array([ 4, 17, 24, ..., 22,  9,  4], dtype=int64)

# %%
tsne_model = TSNE(n_components=2, verbose=1, random_state=33)

# %%
# fit t-SNE model on LDA topics
tsne_lda = tsne_model.fit_transform(topics_distribution)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 3889 samples in 0.080s...
# [t-SNE] Computed neighbors for 3889 samples in 1.188s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3889
# [t-SNE] Computed conditional probabilities for sample 2000 / 3889
# [t-SNE] Computed conditional probabilities for sample 3000 / 3889
# [t-SNE] Computed conditional probabilities for sample 3889 / 3889
# [t-SNE] Mean sigma: 0.094931
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 78.445656
# [t-SNE] KL divergence after 1000 iterations: 1.328979

# %%
tsne_lda_df = pd.DataFrame(tsne_lda, columns=['x1', 'x2'])
tsne_lda_df['dominant_topic'] = dominant_topic

# %%
plt.figure(figsize=(15, 15))

sns.scatterplot(x=tsne_lda_df['x1'], y=tsne_lda_df['x2'], hue=tsne_lda_df['dominant_topic'],
                legend='full', palette=sns.color_palette("hls", 29))

# %% [markdown]
# # Dokument predstavljam raspodelom fraza u okviru najznacajnije teme. Tezina svake reci pomnozena je sa tezinom dominantne teme za trenutni dokument, kako bi se na neki nacin i to uzelo u obzir (moguce je i dodavanje novog featurea, slican je rezultat)

# %%
# num_words = all words in dictionary!
topics = lda_model.show_topics(num_topics=num_topics, num_words=num_terms, formatted=False)
len(topics[0][1])
# Out:
# 7037

# %%
# topics_data je vektor od 29 elemenata, gde je svaki od elemenata vektor tezina svih reci za tu temu
topics_data = []
for topic in topics:
    weights = []
    for pair in topic[1]:
        #print(pair)
        weights.append(pair[1])
    topics_data.append(weights)

# %%
dominant_topic_df = pd.read_csv('dataframes/topics_of_documents.csv')
dominant_topic_df.head()
# Out:
#    dominant_topic  perc_contribution  \
# 0             4.0             0.3999
# 1            17.0             0.2325
# 2            24.0             0.3343
# 3             0.0             0.1887
# 4            21.0             0.1860
#
#                                       topic_keywords     filename  \
# 0  relief, jurisdiction, action, final, dispute, ...     06_1.xml
# 1  report, complaint, letter, request, duty, alle...   06_100.xml
# 2  client, produce, disclosure, privilege, advice...  06_1001.xml
# 3  agreement, contract, clause, obligation, enter...  06_1004.xml
# 4  income, assessment, commissioner, taxpayer, en...  06_1005.xml
#
#                                                 text
# 0  background current application applicant holdi...
# 1  application order review judicial_review conce...
# 2  notice motion file bring first second third ap...
# 3  introduction brand company know come marketing...
# 4  context present application appeal application...

# %%
# svaki dokument predstavlja se raspodelom reci za dominantnu temu tog dokumenta
doc_topic_keywords = []

for index, row in dominant_topic_df.iterrows():
    #document_features = []
    perc_contribution = row['perc_contribution']
    document_features = list(topics_data[int(row['dominant_topic'])])
    
    # mnozenje tezine svake reci sa tezinom dominantne teme
    document_features = [perc_contribution * value for value in document_features]
    
    #document_features.append(row['perc_contribution'])    # ukljucujem i tezinu dominantne teme kao dodatan feature (pored raspodele tezina reci dominantne teme)
    
    doc_topic_keywords.append(document_features)

# %%
len(doc_topic_keywords[333])
# Out:
# 7037

# %%
tsne_topics_model = TSNE(n_components=2, verbose=1, random_state=33)

# %%
tsne_topics_data = tsne_topics_model.fit_transform(doc_topic_keywords)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 3889 samples in 1.348s...
# [t-SNE] Computed neighbors for 3889 samples in 37.937s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3889
# [t-SNE] Computed conditional probabilities for sample 2000 / 3889
# [t-SNE] Computed conditional probabilities for sample 3000 / 3889
# [t-SNE] Computed conditional probabilities for sample 3889 / 3889
# [t-SNE] Mean sigma: 0.000504
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 57.609928
# [t-SNE] KL divergence after 1000 iterations: 0.325506

# %%
tsne_topics_df = pd.DataFrame(tsne_topics_data, columns=['x1', 'x2'])
tsne_topics_df['dominant_topic'] = list(dominant_topic_df['dominant_topic'])
tsne_topics_df.head()
# Out:
#           x1         x2  dominant_topic
# 0  23.767838 -63.649410             4.0
# 1   4.768532  -4.420756            17.0
# 2 -52.549984   4.832052            24.0
# 3  32.103939  -3.658521             0.0
# 4   9.740913  15.742590            21.0

# %%
plt.figure(figsize=(15, 15))

sns.scatterplot(x=tsne_topics_df['x1'], y=tsne_topics_df['x2'], hue=tsne_topics_df['dominant_topic'],
                legend='full', palette=sns.color_palette("hls", 29), alpha=0.5)
#sns.scatterplot(x=tsne_centroids[:, 0], y=tsne_centroids[:, 1], marker='X', s=100, color='darkred')

# %% [markdown]
# # Add cluster for each document into dataframe

# %%
df = pd.read_csv('dataframes/topics_of_documents.csv')
df['cluster'] = labels

df.to_csv('dataframes/topics_clusters_of_documents.csv', index=False)

# %%
df.head(20)
# Out:
#     dominant_topic  perc_contribution  \
# 0              4.0             0.3999
# 1             17.0             0.2325
# 2             24.0             0.3343
# 3              0.0             0.1887
# 4             21.0             0.1860
# 5              9.0             0.4852
# 6             22.0             0.4623
# 7              7.0             0.5708
# 8             18.0             0.2556
# 9             27.0             0.3745
# 10             9.0             0.3948
# 11             9.0             0.5407
# 12             4.0             0.5182
# 13             9.0             0.5294
# 14            12.0             0.4762
# 15            15.0             0.4227
# 16             9.0             0.3956
# 17            13.0             0.3493
# 18            22.0             0.3682
# 19            16.0             0.3787
#
#                                        topic_keywords     filename  \
# 0   relief, jurisdiction, action, final, dispute, ...     06_1.xml
# 1   report, complaint, letter, request, duty, alle...   06_100.xml
# 2   client, produce, disclosure, privilege, advice...  06_1001.xml
# 3   agreement, contract, clause, obligation, enter...  06_1004.xml
# 4   income, assessment, commissioner, taxpayer, en...  06_1005.xml
# 5   tribunal, appellant, finding, error, letter, c...  06_1006.xml
# 6   motion, plead, paragraph, trial, third, defenc...  06_1015.xml
# 7   share, scheme, company, director, meeting, sha...  06_1017.xml
# 8   country, return, political, police, convention...  06_1018.xml
# 9   company, defendant, plaintiff, creditor, asic,...   06_102.xml
# 10  tribunal, appellant, finding, error, letter, c...  06_1021.xml
# 11  tribunal, appellant, finding, error, letter, c...  06_1022.xml
# 12  relief, jurisdiction, action, final, dispute, ...  06_1023.xml
# 13  tribunal, appellant, finding, error, letter, c...  06_1026.xml
# 14  price, sale, product, representation, market, ...  06_1027.xml
# 15  letter, request, extension, requirement, compl...  06_1028.xml
# 16  tribunal, appellant, finding, error, letter, c...  06_1029.xml
# 17  child, family, live, relationship, community, ...  06_1032.xml
# 18  motion, plead, paragraph, trial, third, defenc...  06_1033.xml
# 19  trustee, bankruptcy, trust, bankrupt, debt, de...  06_1041.xml
#
#                                                  text  cluster
# 0   background current application applicant holdi...        4
# 1   application order review judicial_review conce...       14
# 2   notice motion file bring first second third ap...       17
# 3   introduction brand company know come marketing...        0
# 4   context present application appeal application...        4
# 5   appeal judgment barne give include dismissal a...       14
# 6   notice motion file applicant respect file seek...       14
# 7   first second limit hold preference share regio...       17
# 8   application extension time file_serve notice a...       14
# 9   application direction concern fix remuneration...       17
# 10  purport appeal decision magistrate make order ...       14
# 11  appeal decision magistrate make order dismiss ...       14
# 12  court motion file behalf plaintiff seek order ...       14
# 13  appeal judgment handed dismiss application dec...       14
# 14  allege first respondent cambur_industrie cambu...       17
# 15  applicant bear applicant enrol bachelor busine...       17
# 16  application leave pursuant order notice appeal...       17
# 17  appeal order make dismissing application decis...       14
# 18  introduction wearne former member university i...       17
# 19  creditor_petition amend notice state ground op...       14

# %%
# grupisanje po temi i uzimanje dokumenta sa max tezinom u okviru svake grupe
def get_representative_documents(doc_topics_df):
    df = pd.DataFrame()
    grouped_df = doc_topics_df.groupby('dominant_topic')
    for i, grp in grouped_df:
        df = pd.concat([df, grp.sort_values(['perc_contribution'], ascending=[0]).head(1)], axis=0)
    df.reset_index(inplace=True, drop=True)
    df.columns = ['topic', 'perc_contribution', 'topic_keywords', 'filename', 'text', 'cluster']
    return df

representative_docs_df = get_representative_documents(df)
representative_docs_df
# Out:
#     topic  perc_contribution  \
# 0     0.0             0.5201
# 1     1.0             0.3789
# 2     2.0             0.5477
# 3     3.0             0.5816
# 4     4.0             0.6566
# 5     5.0             0.5450
# 6     6.0             0.6227
# 7     7.0             0.7851
# 8     8.0             0.5697
# 9     9.0             0.7721
# 10   10.0             0.4901
# 11   11.0             0.5043
# 12   12.0             0.6582
# 13   13.0             0.5634
# 14   14.0             0.5177
# 15   15.0             0.6824
# 16   16.0             0.5417
# 17   17.0             0.4371
# 18   18.0             0.6051
# 19   19.0             0.7858
# 20   20.0             0.5504
# 21   21.0             0.6148
# 22   22.0             0.7090
# 23   23.0             0.4965
# 24   24.0             0.6838
# 25   25.0             0.5156
# 26   26.0             0.5244
# 27   27.0             0.7304
# 28   28.0             0.7453
#
#                                        topic_keywords     filename  \
# 0   agreement, contract, clause, obligation, enter...   07_136.xml
# 1   business, lease, licence, rent, premise, manag...   09_682.xml
# 2   contravention, penalty, offence, charge, crimi...  06_1732.xml
# 3   word, determination, subsection, statutory, co...  07_1004.xml
# 4   relief, jurisdiction, action, final, dispute, ...    08_47.xml
# 5   patent, product, design, copyright, infringeme...  06_1267.xml
# 6   report, test, line, level, expert, damage, ris...  06_1141.xml
# 7   share, scheme, company, director, meeting, sha...  07_1944.xml
# 8   plan, project, action, condition, shape, tree,...   08_903.xml
# 9   tribunal, appellant, finding, error, letter, c...    09_89.xml
# 10  payment, pay, settlement, credit, money, liabi...  06_1291.xml
# 11  service, customer, market, access, supply, con...    07_38.xml
# 12  price, sale, product, representation, market, ...    08_75.xml
# 13  child, family, live, relationship, community, ...   07_197.xml
# 14  service, work, item, rate, hour, vehicle, day,...   06_132.xml
# 15  letter, request, extension, requirement, compl...   06_350.xml
# 16  trustee, bankruptcy, trust, bankrupt, debt, de...  09_1575.xml
# 17  report, complaint, letter, request, duty, alle...    07_85.xml
# 18  country, return, political, police, convention...   09_644.xml
# 19  tribunal, injury, medical, service, cause, con...  07_1380.xml
# 20  tell, word, ask, name, understand, later, sign...  06_1066.xml
# 21  income, assessment, commissioner, taxpayer, en...    07_41.xml
# 22  motion, plead, paragraph, trial, third, defenc...   08_629.xml
# 23  financial, security, loan, fund, project, asse...   09_276.xml
# 24  client, produce, disclosure, privilege, advice...  09_1161.xml
# 25  property, transfer, offer, sale, land, assignm...  08_1536.xml
# 26  employee, work, site, employment, employer, un...   08_495.xml
# 27  company, defendant, plaintiff, creditor, asic,...  06_1223.xml
# 28  group, area, land, determination, water, peopl...  07_1937.xml
#
#                                                  text  cluster
# 0   second respondent apply court order stay proce...       17
# 1   introduction complex situate open comprise num...        4
# 2   make application court various remedy arise al...       14
# 3   division migration regulation regulation speci...       14
# 4   motion present court seek application leave ap...       14
# 5   follow reason order make applicant appeal cour...       14
# 6   central issue proceeding concern determination...        4
# 7   second hear publish reason judgment order make...       14
# 8   table content introduction application make ad...        4
# 9   appeal order court dismiss appellant applicati...       14
# 10  order make grant leave permanent join responde...       14
# 11  introduction applicant infringement patent say...       17
# 12  introduction large australian retailer jewelle...        4
# 13  act personally decide apply order quash decisi...       14
# 14  court hear mackay application time application...       14
# 15  revised_transcript application leave appeal ju...       14
# 16  dismiss application bankruptcy notice bankrupt...       14
# 17  introduction applicant obieta claim unlawfully...       17
# 18  appeal judgment deliver dismissing application...       17
# 19  judgment court dismiss appeal decision tribuna...       14
# 20  final judgment introduction case concern call ...        4
# 21  limit first applicant payment solution limit s...       17
# 22  proceed long tortuous history commence applica...       14
# 23  introduction proceeding concern subsidiary bhp...        4
# 24  deliver reason make order betfair limited race...       14
# 25  introduction proceeding bring number retiree e...        4
# 26  issue determination proceeding assessment appr...       14
# 27  case hear together raise question determinatio...       14
# 28  proceeding arise application determination mak...       14

# %%
values, counts = np.unique(labels, return_counts=True)

for val, cnt in zip(values, counts):
    print('{} - {}'.format(val, cnt))
# Out:
# 0 - 40
# 1 - 1
# 2 - 14
# 3 - 1
# 4 - 425
# 5 - 1
# 6 - 1
# 7 - 117
# 8 - 1
# 9 - 1
# 10 - 155
# 11 - 1
# 12 - 1
# 13 - 1
# 14 - 1573
# 15 - 1
# 16 - 1
# 17 - 1511
# 18 - 1
# 19 - 1
# 20 - 1
# 21 - 1
# 22 - 1
# 23 - 11
# 24 - 1
# 25 - 1
# 26 - 21
# 27 - 1
# 28 - 1
# 29 - 2
